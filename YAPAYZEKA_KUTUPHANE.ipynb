# %%
print("Merhaba, İGÜ - YAPAY ZEKA geliştirilmesi için kullanılacak kütüphaneler")
# Out:
# Merhaba, İGÜ - YAPAY ZEKA geliştirilmesi için kullanılacak kütüphaneler

# %%
import sys
print(sys.version)
# Out:
# 3.10.12 (main, Sep 11 2024, 15:47:36) [GCC 11.4.0]

# %%
from google.colab import drive # gogole colab - drive bağlantısı
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.chdir('/content/drive/My Drive/YAPAYZEKA_KÜTÜPHANE')
# !pwd # bize kodun çıktısıı dosya yolu olarak veren kod blogudur.
# Out:
# /content/drive/My Drive/YAPAYZEKA_KÜTÜPHANE

# %% [markdown]
# PANDAS
#
# 1.VERİ YAPILARI
#
# 2.VERİ OKUMA YAZMA
#
# 3.VERİ SEÇME,BİRLEŞTİRME,DÖNÜŞTÜRME,TEMİZLEME VE FİLTRELEME
#
# 4.VERİ ANELİZİ
#
# 5.İSTATİKSEL HESAPLAMA
#
#
# PANDAS VERİ ANALİZİ FONKSİYONLARI
#
# 1.df['Not'].min() # endüşük değeri bulur
#
# 2.df['Not'].mean() # ortalama değeri hesaplar
#
# 3.df['Not'].median() # medyanı bulur
#
# 4.df['Not'].std() # standart sapmayı hesaplar
#
# 5.df['Not'].sum() # toplam değeri bulur
#
# 6.df.describe() # veri setinin özet istatisklerini verir

# %%
import pandas as pd
# ulasın ders notu bılgılerı

data = {'Ders': ['Algoritma', 'BilgisayarProgramlama', 'Elektronik-2', 'AviyonikSistemler'],
        'Not': [95, 100, 65, 90]}
# veriyi bir dataFrame'e dönüştürür
df = pd.DataFrame(data)
# en yüksek notu bul
en_yuksek_not = df['Not'].max()
print("En yüksek not:", en_yuksek_not)
# ortalama notu hesapla
ortalama_not = df['Not'].mean()
print("Ortalama not:", ortalama_not)
print(df.describe())
# Out:
# En yüksek not: 100
# Ortalama not: 87.5
#               Not
# count    4.000000
# mean    87.500000
# std     15.545632
# min     65.000000
# 25%     83.750000
# 50%     92.500000
# 75%     96.250000
# max    100.000000

# %% [markdown]
# NUMPY Kullanım Alanları:
#
# 1. Çok boyutlu dizil

# %%
import numpy as np
# rastgele tanımlama değer - sıralaması olmayan
dizi = np.array([1, -55, 9, -23, 13, -21, 23, 37, 29, -6])
# dizinin ortalama sonuç
ortalama = np.mean(dizi)
print("Ortalama:", ortalama)
# dizinin standart sapma
std_sapma = np.std(dizi)
print("Standart Sapma:", std_sapma)
# dizinin mutlagını al
mutlak_veriler = np.abs(dizi)
print("Mutlak Deger Cıktısı:", mutlak_veriler)
# Out:
# Ortalama: 0.7
# Standart Sapma: 26.487921775783015
# Mutlak Deger Cıktısı: [ 1 55  9 23 13 21 23 37 29  6]

# %% [markdown]
# MATPLOTLİB

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title('Sinüs Grafiği')
plt.xlabel('X Ekseni')
plt.ylabel('Y Ekseni')
plt.grid(True) # arkasınada ki kareyi kaldırmak için False yazılır
plt.show()

# %%
import matplotlib.pyplot as plt

yillar = [2018, 2019, 2020, 2021, 2022]
satislar = [103, 120, 100, -200, 115]

plt.plot(yillar, satislar, marker='o')

plt.title("Yıllara Göre Satışlar")
plt.xlabel("Yıllar")
plt.ylabel("Satış Miktarı")

plt.show()
